# %% [markdown]
# # Interactive Map of Parks Using Folium
#
# This notebook demonstrates creating an interactive map of parks using Folium, based on data from OpenStreetMap (OSM). Additionally, we include functionality for user input to customize aspects of the map.

# %%
# !pip install folium

# %%
import folium
import geopandas as gpd
from IPython.display import display

# Load the GeoJSON data into a GeoDataFrame
gdf = gpd.read_file('export.geojson')

# Function to create and display the map
def create_map(center=[40.7128, -74.0060], zoom=12):
    m = folium.Map(location=center, zoom_start=zoom)
    for _, park in gdf.iterrows():
        centroid = park['geometry'].centroid
        folium.Marker(
            location=[centroid.y, centroid.x],
            popup=park['name'],
            tooltip=park['name']
        ).add_to(m)
    display(m)

# %%
# User input for center of the map
user_lat = float(input('Enter the latitude for the map center: '))
user_lon = float(input('Enter the longitude for the map center: '))
user_zoom = int(input('Enter the zoom level for the map: '))

create_map(center=[user_lat, user_lon], zoom=user_zoom)
# Out:
# Enter the latitude for the map center: 1
# Enter the longitude for the map center: 1
# Enter the zoom level for the map: 1
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9dcb9b79f53b297670305d3b28f68414 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9dcb9b79f53b297670305d3b28f68414&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9dcb9b79f53b297670305d3b28f68414 = L.map(
#                 &quot;map_9dcb9b79f53b297670305d3b28f68414&quot;,
#                 {
#                     center: [1.0, 1.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f086a828126703f4f018c89c615e3ec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5f086a828126703f4f018c89c615e3ec.addTo(map_9dcb9b79f53b297670305d3b28f68414);
#
#
#             var marker_e4a80c1f9f32936774ef003246fbbbc6 = L.marker(
#                 [40.76920497886911, -73.9495438127366],
#                 {}
#             ).addTo(map_9dcb9b79f53b297670305d3b28f68414);
#
#
#         var popup_287e2b9ff22c605e7f0969a2f57c1ff3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bcc76bf0ad79485ea65b95b7ba82308c = $(`&lt;div id=&quot;html_bcc76bf0ad79485ea65b95b7ba82308c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;John Jay Park&lt;/div&gt;`)[0];
#                 popup_287e2b9ff22c605e7f0969a2f57c1ff3.setContent(html_bcc76bf0ad79485ea65b95b7ba82308c);
#
#
#
#         marker_e4a80c1f9f32936774ef003246fbbbc6.bindPopup(popup_287e2b9ff22c605e7f0969a2f57c1ff3)
#         ;
#
#
#
#
#             marker_e4a80c1f9f32936774ef003246fbbbc6.bindTooltip(
#                 `&lt;div&gt;
#                      John Jay Park
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5e4e8c4737f4bdaab34161e4dbfb1122 = L.marker(
#                 [40.719563189007346, -73.99266175457157],
#                 {}
#             ).addTo(map_9dcb9b79f53b297670305d3b28f68414);
#
#
#         var popup_fe1c6232611cc71816385903eb3af843 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_685d24a8b226d608118ebcb96b417083 = $(`&lt;div id=&quot;html_685d24a8b226d608118ebcb96b417083&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sara D. Roosevelt Park&lt;/div&gt;`)[0];
#                 popup_fe1c6232611cc71816385903eb3af843.setContent(html_685d24a8b226d608118ebcb96b417083);
#
#
#
#         marker_5e4e8c4737f4bdaab34161e4dbfb1122.bindPopup(popup_fe1c6232611cc71816385903eb3af843)
#         ;
#
#
#
#
#             marker_5e4e8c4737f4bdaab34161e4dbfb1122.bindTooltip(
#                 `&lt;div&gt;
#                      Sara D. Roosevelt Park
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0ac61d296b33a8e421058f942cd89dd0 = L.marker(
#                 [40.70473828377181, -74.00664264116347],
#                 {}
#             ).addTo(map_9dcb9b79f53b297670305d3b28f68414);
#
#
#         var popup_88ed8126b1f5e5eb247b56082ddced72 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2feb081119938b55a1d1bc9b95f19a17 = $(`&lt;div id=&quot;html_2feb081119938b55a1d1bc9b95f19a17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mannahatta Park&lt;/div&gt;`)[0];
#                 popup_88ed8126b1f5e5eb247b56082ddced72.setContent(html_2feb081119938b55a1d1bc9b95f19a17);
#
#
#
#         marker_0ac61d296b33a8e421058f942cd89dd0.bindPopup(popup_88ed8126b1f5e5eb247b56082ddced72)
#         ;
#
#
#
#
#             marker_0ac61d296b33a8e421058f942cd89dd0.bindTooltip(
#                 `&lt;div&gt;
#                      Mannahatta Park
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0e7df295f3d1cdab0b14ba1151571a55 = L.marker(
#                 [40.752326040808214, -73.96881150138722],
#                 {}
#             ).addTo(map_9dcb9b79f53b297670305d3b28f68414);
#
#
#         var popup_bf28f1670d1c10ecc63d2b9954166860 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c8920da65cfbe62e8dc5b0a91c5a3acd = $(`&lt;div id=&quot;html_c8920da65cfbe62e8dc5b0a91c5a3acd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dag Hammarskjold Plaza&lt;/div&gt;`)[0];
#                 popup_bf28f1670d1c10ecc63d2b9954166860.setContent(html_c8920da65cfbe62e8dc5b0a91c5a3acd);
#
#
#
#         marker_0e7df295f3d1cdab0b14ba1151571a55.bindPopup(popup_bf28f1670d1c10ecc63d2b9954166860)
#         ;
#
#
#
#
#             marker_0e7df295f3d1cdab0b14ba1151571a55.bindTooltip(
#                 `&lt;div&gt;
#                      Dag Hammarskjold Plaza
#                  &lt;/div&gt;`,
#                 {&quot;stick

# %% [markdown]
# Note: For the input functionality to work interactively in Jupyter, ensure you run this notebook in an environment that supports IPython's `input` function, such as Jupyter Notebook or JupyterLab.
